# %% [raw]
# ---
# title: Show image
# description: Display nice images notebook
# show-code: False
# params:
#     image_filename:
#         input: file
#         label: Please upload a photo
#         maxFileSize: 10MB
#     name:
#         input: text
#         label: Please provide title
# ---

# %%
image_filename = "beach.jpg"
name = "Piotr"

# %%
from IPython.display import Markdown as md
md(f"# {name}, it is nice to be here")
# Out:
# # Piotr it is nice to be here

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.figure(figsize=(12, 8), dpi=80)
img = mpimg.imread(image_filename)
imgplot = plt.imshow(img)
plt.axis('off')
plt.show()
